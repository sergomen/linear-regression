# %%
import matplotlib.pyplot as mp
import numpy as np
x = np.linspace( -10 , 10 , 5 )
y = 2*x + 5
mp.plot( x , y , 'o' )

# %%
x = np.linspace( -10 , 10 , 5 )
y = 2*x + 5
np.polyfit(x,y,2)
# Out:
# array([2.07147633e-17, 2.00000000e+00, 5.00000000e+00])

# %%
xn = np.linspace(-20,20,100)
yn = np.poly1d(coeff)
mp.plot( xn,yn(xn),x,y,'o')
# Out:
# [<matplotlib.lines.Line2D at 0x1e277636080>,
#  <matplotlib.lines.Line2D at 0x1e2776360e0>]

# %%
np.random.seed(12)
x = np.linspace( 0, 1, 25 )
y = np.cos(x) + 0.3*np.random.rand(25)
z = np.polyfit(x, y, 4)
p = np.poly1d( np.polyfit(x, y, 4) )
t = np.linspace(0, 1, 250)
mp.plot(x, y, 'o', t, p(t), '-')
mp.show()

# %%
p
# Out:
# poly1d([-0.15348246,  0.30774178, -1.0035372 ,  0.33004769,  1.10155642])
